# %% [markdown]
# <a href="https://colab.research.google.com/github/Octa-p/Baby/blob/main/MidTerm_Baby2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# # **Data_Preprocessing**

# %% [markdown]
# ## ความกดอากาศแต่ละจังหวัด

# %% [markdown]
# ### ขอนแก่น

# %%
Press_air_KK = pd.read_excel('/content/drive/MyDrive/อุตุ/อุตุ-20240209T172606Z-001/อุตุ/ความกด(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx')

# %%
Press_air_KK
# Out:
#    ความกด(เปอร์เซ็นต์)                Unnamed: 1           Unnamed: 2  \
# 0              รายวัน                        NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  ที่                     สถานี             เดือน/ปี
# 3                  NaN                       NaN                  NaN
# 4                  1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00
# 5                  2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00
# 6                  3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00
# 7                  1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00
# 8                  2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00
# 9                  3    352201-หนองคาย จ.หนองคาย  2012-10-01 00:00:00
# 10                 4    352201-หนองคาย จ.หนองคาย  2012-11-01 00:00:00
# 11                 5    352201-หนองคาย จ.หนองคาย  2012-12-01 00:00:00
# ...

# %% [markdown]
# ### ทำการเปลี่ยนชื่อ Column

# %%
Press_air_KK.rename(columns={'Unnamed: 1':'สถานี','Unnamed: 2':'เดือน/ปี'}, inplace=True)
Press_air_KK
# Out:
#    ความกด(เปอร์เซ็นต์)                     สถานี             เดือน/ปี  \
# 0              รายวัน                        NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  ที่                     สถานี             เดือน/ปี
# 3                  NaN                       NaN                  NaN
# 4                  1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00
# 5                  2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00
# 6                  3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00
# 7                  1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00
# 8                  2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00
# 9                  3    352201-หนองคาย จ.หนองคาย  2012-10-01 00:00:00
# 10                 4    352201-หนองคาย จ.หนองคาย  2012-11-01 00:00:00
# 11                 5    352201-หนองคาย จ.หนองคาย  2012-12-01 00:00:00
# ...

# %%
Press_air_KK.rename(columns={'Unnamed: 34':'เฉลี่ย',}, inplace=True)

# %%
Press_air_KK.rename(columns={'Unnamed: 3':'1', 'Unnamed: 4':'2',
       'Unnamed: 5':'3', 'Unnamed: 6':'4', 'Unnamed: 7':'5', 'Unnamed: 8':'6', 'Unnamed: 9':'7',
       'Unnamed: 10':'8', 'Unnamed: 11':'9', 'Unnamed: 12':'10', 'Unnamed: 13':'11',
       'Unnamed: 14':'12', 'Unnamed: 15':'13', 'Unnamed: 16':'14', 'Unnamed: 17':'15',
       'Unnamed: 18':'16', 'Unnamed: 19':'17', 'Unnamed: 20':'18', 'Unnamed: 21':'19',
       'Unnamed: 22':'20', 'Unnamed: 23':'21', 'Unnamed: 24':'22', 'Unnamed: 25':'23',
       'Unnamed: 26':'24', 'Unnamed: 27':'25', 'Unnamed: 28':'26', 'Unnamed: 29':'27',
       'Unnamed: 30':'28', 'Unnamed: 31':'29', 'Unnamed: 32':'30', 'Unnamed: 33':'31'}, inplace=True)

# %%
Press_air_KK.head()
# Out:
#   ความกด(เปอร์เซ็นต์)                     สถานี             เดือน/ปี        1  \
# 4                 1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00  1005.47
# 5                 2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00  1011.79
# 6                 3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00  1011.43
# 7                 1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00  1015.67
# 8                 2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00  1013.26
#
#          2        3        4        5        6        7  ...       23  \
# 4  1006.65  1007.49  1008.28  1009.88  1011.36  1011.17  ...  1010.76
# 5  1010.83  1010.74  1010.71  1010.09  1009.24  1008.03  ...  1014.07
# 6  1012.57  1012.28  1012.97  1013.09  1012.03  1012.05  ...  1012.88
# 7  1014.11  1012.91  1014.06  1015.51  1015.88  1017.72  ...  1010.91
# 8  1012.92  1013.61  1013.18  1011.26  1008.80  1008.16  ...  1005.75
#
# ...

# %% [markdown]
# ### ทำการตัดแถวที่ไม่ใช้ออก

# %%
Press_air_KK.index
# Out:
# RangeIndex(start=0, stop=59, step=1)

# %%
Press_air_KK.columns
# Out:
# Index(['ความกด(เปอร์เซ็นต์)', 'สถานี', 'เดือน/ปี', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'เฉลี่ย'],
#       dtype='object')

# %%
Press_air_KK.drop(0, inplace=True)

# %%
Press_air_KK.drop(1, inplace=True)

# %%
Press_air_KK.drop(2, inplace=True)

# %%
Press_air_KK.drop(3, inplace=True)

# %%
Press_air_KK.head()
# Out:
#   ความกด(เปอร์เซ็นต์)                     สถานี             เดือน/ปี        1  \
# 4                 1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00  1005.47
# 5                 2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00  1011.79
# 6                 3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00  1011.43
# 7                 1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00  1015.67
# 8                 2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00  1013.26
#
#          2        3        4        5        6        7  ...       23  \
# 4  1006.65  1007.49  1008.28  1009.88  1011.36  1011.17  ...  1010.76
# 5  1010.83  1010.74  1010.71  1010.09  1009.24  1008.03  ...  1014.07
# 6  1012.57  1012.28  1012.97  1013.09  1012.03  1012.05  ...  1012.88
# 7  1014.11  1012.91  1014.06  1015.51  1015.88  1017.72  ...  1010.91
# 8  1012.92  1013.61  1013.18  1011.26  1008.80  1008.16  ...  1005.75
#
# ...

# %% [markdown]
# ### ตรวจค่า Missing

# %%
Press_air_KK.shape
# Out:
# (55, 35)

# %%
Press_air_KK .isnull().any()
# Out:
# ความกด(เปอร์เซ็นต์)    False
# สถานี                  False
# เดือน/ปี               False
# Unnamed: 3             False
# Unnamed: 4             False
# Unnamed: 5             False
# Unnamed: 6             False
# Unnamed: 7             False
# Unnamed: 8             False
# Unnamed: 9             False
# Unnamed: 10            False
# Unnamed: 11            False
# Unnamed: 12            False
# Unnamed: 13            False
# Unnamed: 14            False
# Unnamed: 15            False
# Unnamed: 16            False
# Unnamed: 17            False
# Unnamed: 18            False
# Unnamed: 19            False
# Unnamed: 20            False
# Unnamed: 21            False
# Unnamed: 22            False
# Unnamed: 23            False
# Unnamed: 24            False
# Unnamed: 25            False
# Unnamed: 26            False
# Unnamed: 27            False
# Unnamed: 28            False
# Unnamed: 29            False
# Unnamed: 30            False
# Unnamed: 31            False
# ...

# %%
Press_air_KK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 4 to 58
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ความกด(เปอร์เซ็นต์)  55 non-null     object
#  1   สถานี                55 non-null     object
#  2   เดือน/ปี             55 non-null     object
#  3   Unnamed: 3           55 non-null     object
#  4   Unnamed: 4           55 non-null     float64
#  5   Unnamed: 5           55 non-null     float64
#  6   Unnamed: 6           55 non-null     float64
#  7   Unnamed: 7           55 non-null     float64
#  8   Unnamed: 8           55 non-null     float64
#  9   Unnamed: 9           55 non-null     float64
#  10  Unnamed: 10          55 non-null     float64
#  11  Unnamed: 11          55 non-null     float64
#  12  Unnamed: 12          55 non-null     float64
#  13  Unnamed: 13          55 non-null     float64
#  14  Unnamed: 14          55 non-null     float64
# ...

# %% [markdown]
# ### จะพบว่าไม่มีค่า Missing เลย เพราะข้อมูลไม่ได้ถูกปล่อยให้ว่างไว้ แต่ค่าที่ไม่มีข้อมูลจะทำการใส่ "-" แทน โดย Column ที่ไม่มีข้อมูลนั้นจะเป็นข้อมูลระหว่างวันที่ 29-31 เนื่องจากในแต่ละเดือนมีจำนวนวันที่ไม่เท่ากัน จึงไม่มีข้อมูล

# %% [markdown]
# ### ดังนั้น จึงต้องทำการนำค่าเฉลี่ยของความกดอากาศมาใส่แทนที่ค่าที่ไม่มีข้อมูล โดยการทำให้ "-" เป็นค่า NaN

# %%
import numpy as np

# %%
air_Nan_KK = Press_air_KK.replace('-',np.NaN)

# %% [markdown]
# ### ตรวจหา Missing อีกครั้ง

# %%
air_Nan_KK.isnull().any()
# Out:
# ความกด(เปอร์เซ็นต์)    False
# สถานี                  False
# เดือน/ปี               False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
# 10                     False
# 11                     False
# 12                     False
# 13                     False
# 14                     False
# 15                     False
# 16                     False
# 17                     False
# 18                     False
# 19                     False
# 20                     False
# 21                     False
# 22                     False
# 23                     False
# 24                     False
# 25                     False
# 26                     False
# 27                     False
# 28                     False
# 29                      True
# ...
